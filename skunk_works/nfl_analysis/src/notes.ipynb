# %%
import pandas as pd

df = pd.read_parquet('../data/parquet/players.parquet')

# df[df['game_id'] == '201909080car']
df[df['player_id'] == 'BrowJo02']
# Out:
#         game_date season week time_code       game_id player_id pos  \
# 223    2019-09-08   2019   01   2019001  201909080nyj  BrowJo02  WR
# 579    2019-09-15   2019   02   2019002  201909150nyg  BrowJo02  WR
# 803    2019-09-22   2019   03   2019003  201909220buf  BrowJo02  WR
# 1199   2019-09-29   2019   04   2019004  201909290buf  BrowJo02  WR
# 1689   2019-10-06   2019   05   2019005  201910060oti  BrowJo02  WR
# 2246   2019-10-20   2019   07   2019007  201910200buf  BrowJo02  WR
# 2575   2019-10-27   2019   08   2019008  201910270buf  BrowJo02  WR
# 2900   2019-11-03   2019   09   2019009  201911030buf  BrowJo02  WR
# 3276   2019-11-10   2019   10   2019010  201911100cle  BrowJo02  WR
# 3616   2019-11-17   2019   11   2019011  201911170mia  BrowJo02  WR
# 3907   2019-11-24   2019   12   2019012  201911240buf  BrowJo02  WR
# 4208   2019-11-28   2019   13   2019013  201911280dal  BrowJo02  WR
# 4620   2019-12-08   2019   14   2019014  201912080buf  BrowJo02  WR
# ...

# %%
import pandas as pd

df = pd.read_parquet('../data/parquet/players.parquet')

df['pos'].unique()
# Out:
# array(['QB', 'RB', 'WR', 'TE', 'FB', 'SS', 'G', 'T', 'K', 'CB', 'P', 'FS',
#        'NT', 'C', 'DE', 'LB', 'DB', 'HB', 'RB/W', 'OL', 'S', 'WR/R',
#        'FB/D', 'LB/F', 'FB/R', 'C/G', 'G/T', 'DT'], dtype=object)

# %%
import pandas as pd

df = pd.read_parquet('../data/parquet/games.parquet')
# Out:
#       game_date season week       game_id  Vegas_Line Vegas_Favorite  \
# 0    2019-09-05   2019  w01  201909050chi        -3.5            CHI
# 1    2019-09-08   2019  w01  201909080car        -1.5            LAR
# 2    2019-09-08   2019  w01  201909080cle        -5.5            CLE
# 3    2019-09-08   2019  w01  201909080crd        -2.5            DET
# 4    2019-09-08   2019  w01  201909080dal        -7.0            DAL
# ..          ...    ...  ...           ...         ...            ...
# 979  2022-11-20   2022  w11  202211200nyg         NaN           None
# 980  2022-11-20   2022  w11  202211200pit         NaN           None
# 981  2022-11-20   2022  w11  202211200rav         NaN           None
# 982  2022-11-20   2022  w11  202211200sdg         NaN           None
# 983  2022-11-21   2022  w11  202211210crd         NaN           None
#
#      Over_Under home_team  home_score vis_team  vis_score
# 0          47.0       CHI           3      GNB         10
# ...
