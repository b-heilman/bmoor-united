# %%
import sys
import os
import pandas as pd

# Get the directory of the current notebook
notebook_dir = os.path.dirname(os.path.abspath("__file__"))

# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, ".."))

run_results = pd.read_parquet(
    os.path.abspath(
        os.path.join(notebook_dir, "../../cache/parquet/after_analytics.parquet")
    )
)

run_results
# Out:
#      labels  expect  probability  prediction  \
# 0      -1.0   False    -0.000756       False
# 1       0.8    True     0.480598        True
# 2       1.0    True    -0.040241       False
# 3       0.3   False    -0.121544       False
# 4       1.0    True    -0.033962       False
# ..      ...     ...          ...         ...
# 412    -1.0   False     0.858640        True
# 413    -0.9   False    -0.028845       False
# 414     1.0    True    -0.079940       False
# 415     0.7    True    -0.031890       False
# 416     0.9    True     0.457052        True
#
#                                                   home  \
# 0    [172.06664, -1.7580993, -1.6629703, -1.7580993...
# 1    [-1.7580993, 252.97702, -1.7580993, 98.47862, ...
# 2    [-1.7580993, -1.7580993, -1.7580993, 237.47458...
# 3    [17.02939, -1.7580993, 14.123658, -1.7580993, ...
# 4    [216.5624, 324.3322, -1.7580993, -1.7580993, 1...
# ..                                                 ...
# 412  [-1.7580993, 99.605835, -1.7580993, 123.32582,...
# 413  [150.7151, -1.7580993, -1.7580993, -1.7580993,...
# 414  [-1.7580993, -1.7580993, -1.7580993, -1.758099...
# 415  [101.742485, -1.7580993, -1.5428994, -1.758099...
# 416  [-1.7580993, -1.7580993, -1.7580993, -1.758099...
#
#                                                   away
# 0    [-1.7580993, -1.7580993, -1.7580993, 168.53677...
# 1    [-1.7580993, 74.69064, -1.7258399, -1.758087, ...
# 2    [-1.7580993, 62.846085, -1.7580993, -1.7575729...
# 3    [-1.7580993, -1.7580993, -1.7580993, 297.12042...
# 4    [-1.7580993, -1.7580993, -1.7580993, 37.07495,...
# ..                                                 ...
# 412  [-1.7580993, -1.7580993, -1.7580993, 121.25917...
# 413  [-1.7580993, -1.7580993, -1.7580993, 107.47029...
# 414  [-1.7580993, 65.87531, -1.7580993, 8.9042, -1....
# 415  [-1.7580993, 68.03768, -1.7580993, -1.7580993,...
# 416  [106.480194, -1.0376179, 28.985231, -1.7580993...
#
# [417 rows x 6 columns]

# %%
import seaborn as sbn

# %%
sbn.displot(data=run_results, x="labels", hue="expect", kind="kde", cut=0)

# %%
sbn.displot(data=run_results, x="probability", hue="expect", kind="kde", cut=0)

# %%
sbn.displot(data=run_results, x="labels", y="probability", hue="expect")
