# %%
import sys
import os
import pandas as pd

# Get the directory of the current notebook
notebook_dir = os.path.dirname(os.path.abspath("__file__"))

# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, ".."))

run_results = pd.read_parquet(
    os.path.abspath(
        os.path.join(notebook_dir, "../../cache/parquet/after_analytics.parquet")
    )
)

run_results
# Out:
#      labels  expect  probabily  prediction  \
# 0       0.7    True   0.256568       False
# 1       0.0   False   0.191254       False
# 2       0.0   False   0.133022       False
# 3       0.7    True   0.505668        True
# 4       0.0   False   0.534845        True
# ..      ...     ...        ...         ...
# 412     0.3   False   0.141701       False
# 413     0.0   False   0.066394       False
# 414     0.6    True   0.168510       False
# 415     0.0   False   0.132766       False
# 416     0.6    True   0.404292        True
#
#                                                   home  \
# 0    [0.9243987, 0.006077635, 0.9975426, 0.03643167...
# 1    [0.958632, 0.006463775, 0.99165654, 0.07994311...
# 2    [0.986826, 0.0034808395, 0.9966073, 0.03479413...
# 3    [0.99219984, 0.0034111429, 0.99574417, 0.02617...
# 4    [0.1404577, 0.006706928, 0.9798259, 0.40096238...
# ..                                                 ...
# 412  [0.9731766, 0.005167412, 0.9966478, 0.05396599...
# 413  [0.98403, 0.0043347874, 0.9963819, 0.044154435...
# 414  [0.9968695, 0.0010269001, 0.9990201, 0.0066656...
# 415  [0.97548485, 0.0017298893, 0.99922335, 0.01550...
# 416  [0.2560518, 0.017620098, 0.9900503, 0.30038735...
#
#                                                   away
# 0    [0.00045509418, 0.9999137, 3.717281e-05, 0.938...
# 1    [0.0034788274, 0.99094075, 0.0024223826, 0.852...
# 2    [0.0035104041, 0.9977448, 0.00079059793, 0.790...
# 3    [0.37584406, 0.6073567, 0.34687275, 0.3131864,...
# 4    [3.3572804e-05, 0.99999785, 1.7062473e-05, 0.9...
# ..                                                 ...
# 412  [0.00012786228, 0.99999166, 2.0602487e-05, 0.9...
# 413  [0.00034310026, 0.9999896, 0.00017344224, 0.99...
# 414  [0.2606738, 0.989899, 0.020101137, 0.62438107,...
# 415  [0.0022101526, 0.9950165, 0.00074527075, 0.676...
# 416  [0.13507755, 0.9886874, 0.017284837, 0.6584986...
#
# [417 rows x 6 columns]

# %%
import seaborn as sbn

# %%
sbn.displot(data=run_results, x='labels', hue='expect', kind="kde")

# %%
sbn.displot(data=run_results, x='probabily', hue='expect', kind="kde")

# %%
sbn.displot(data=run_results, x="labels", y="probability", hue='expect')
